# %% [markdown]
# Preprocess the Global Database of Soil Respiration Data (V5): https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1827.

# %%
from pathlib import Path
import pandas as pd

from pprint import pprint

# %% [markdown]
# # Files and directories

# %%
f_data = Path("./SRDB_V5_1827/data/srdb-data-V5.csv")

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv(f_data)
df.index = df["Site_ID"]
df.head()
# Out:
# /var/folders/b7/q6wyxw8x1_s5rh1mqvfb8vsr0000gn/T/ipykernel_45164/3755053651.py:1: DtypeWarning: Columns (4,39,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_data)
#                Record_number  Entry_date  Study_number         Author  \
# Site_ID
# CA-BND-3YRWD             1.0  2008-09-26          2534  Bond-Lamberty
# CA-BND-6YRWD             2.0  2008-09-26          2534  Bond-Lamberty
# CA-BND-12YRWD            3.0  2008-09-26          2534  Bond-Lamberty
# CA-BND-20YRWD            4.0  2008-09-26          2534  Bond-Lamberty
# CA-BND-37YRWD            5.0  2008-09-26          2534  Bond-Lamberty
#
#               Duplicate_record Quality_flag Contributor Country    Region  \
# Site_ID
# CA-BND-3YRWD               NaN          Q02         BBL  Canada  Manitoba
# CA-BND-6YRWD               NaN          Q02         BBL  Canada  Manitoba
# CA-BND-12YRWD              NaN          Q02         BBL  Canada  Manitoba
# CA-BND-20YRWD              NaN          Q02         BBL  Canada  Manitoba
# CA-BND-37YRWD              NaN          Q02         BBL  Canada  Manitoba
#
#                       Site_name  ...    BA  C_veg_total    C_AG   C_BG   C_CR  \
# Site_ID                          ...
# CA-BND-3YRWD   BOREAS NSA-D1998  ...   0.0        200.0    80.0  120.0   70.0
# CA-BND-6YRWD   BOREAS NSA-D1995  ...   0.5        160.0    90.0   70.0   40.0
# CA-BND-12YRWD  BOREAS NSA-D1989  ...   0.0        520.0   400.0  120.0   70.0
# CA-BND-20YRWD  BOREAS NSA-D1981  ...   4.1       1050.0   700.0  350.0  230.0
# CA-BND-37YRWD  BOREAS NSA-D1964  ...  11.6       2300.0  1500.0  800.0  600.0
#
#                 C_FR C_litter C_soilmineral  C_soildepth  \
# Site_ID
# CA-BND-3YRWD    50.0      NaN       41800.0         70.0
# CA-BND-6YRWD    30.0      NaN       41800.0         70.0
# CA-BND-12YRWD   50.0      NaN       41800.0         70.0
# CA-BND-20YRWD  120.0      NaN       41800.0         70.0
# CA-BND-37YRWD  200.0      NaN       41800.0         70.0
#
#                                                            Notes
# Site_ID
# CA-BND-3YRWD   LAI from Bond-Lamberty (2002); C from Wang (20...
# CA-BND-6YRWD   LAI from Bond-Lamberty (2002); C from Wang (20...
# CA-BND-12YRWD  LAI from Bond-Lamberty (2002); C from Wang (20...
# CA-BND-20YRWD  LAI from Bond-Lamberty (2002); C from Wang (20...
# CA-BND-37YRWD  LAI from Bond-Lamberty (2002); C from Wang (20...
#
# [5 rows x 85 columns]

# %% [markdown]
# # Get predictors and predictands data

# %%
# Predictors
predictors = [
    "Latitude", "Longitude", "MAT", "MAP", "Annual_coverage", "Soil_BD"
    # "Study_temp", "Study_precip", "Chamber_area", "Time_of_day", "LAI",
    # "Age_disturbance", "Elevation", "Soil_BD", "Soil_CN", 
    # "Soil_sand", "Soil_silt", "Soil_clay",  "C_AG", "C_BG"
]

# Predictands
predictands = [
    "Rs_annual"
    # , "Ra_annual", "Rh_annual", "GPP"
]

# %%
# Take the mean of all samples at each site, hoping to reduce the nan values
df_selected = df[predictors+predictands]
df_selected = df_selected.groupby('Site_ID').mean()
df_selected_nona = df_selected.dropna(axis=0)
df_selected_nona
# Out:
#                 Latitude  Longitude   MAT     MAP  Annual_coverage  Soil_BD  \
# Site_ID
# AU-HOS           -12.485    130.940  31.5  1700.0              1.0     1.41
# AU-RMK-ICBURN    -34.010    140.983  17.5   242.0              1.0     1.60
# AU-RMK-ICCK      -34.000    140.966  17.5   242.0              1.0     1.60
# AU-RMK-UCBURN    -34.010    140.983  17.5   242.0              1.0     1.60
# AU-RMK-UCCK      -34.000    140.966  17.5   242.0              1.0     1.60
# ...                  ...        ...   ...     ...              ...      ...
# US-WRCCR-40YR     45.820   -121.950   8.7  2500.0              1.0     1.00
# US-WRCCR-500YR    45.820   -121.950   8.7  2500.0              1.0     0.86
# ZA-PTZ-AB        -30.400     24.400  16.0   694.0              1.0     1.07
# ZA-PTZ-AM        -30.400     24.400  16.0   694.0              1.0     1.15
# ZA-PTZ-CK        -30.400     24.400  16.0   694.0              1.0     1.00
#
#                 Rs_annual
# Site_ID
# AU-HOS            1430.00
# AU-RMK-ICBURN      337.00
# AU-RMK-ICCK        375.00
# AU-RMK-UCBURN      571.00
# AU-RMK-UCCK        598.00
# ...                   ...
# US-WRCCR-40YR      883.00
# US-WRCCR-500YR    1194.00
# ZA-PTZ-AB          885.54
# ZA-PTZ-AM          912.03
# ZA-PTZ-CK          681.18
#
# [823 rows x 7 columns]

# %%
# Save the data
df_selected_nona.to_csv("./selected_SRDB.csv")

# %%
df.isna().sum(axis=0).sort_values()[:40]
# Out:
# Record_number            0
# Entry_date               0
# Study_number             0
# Contributor              0
# Site_ID                  0
# Author                   2
# Country                 11
# Ecosystem_type          88
# Ecosystem_state        109
# YearsOfData            182
# Study_midyear          183
# Biome                  201
# Soil_drainage          223
# Stage                  232
# Meas_method            238
# Leaf_habit             301
# Latitude               381
# Longitude              383
# Species                650
# Site_name             1406
# Annual_coverage       2165
# MAP                   2241
# Soil_type             2311
# Region                2805
# Meas_interval         2821
# Chamber_area          2824
# MAT                   2930
# Collar_depth          4006
# Elevation             4552
# Rs_annual             4625
# Collar_height         5856
# Age_disturbance       6023
# Manipulation          6579
# Notes                 6995
# Rs_growingseason      7699
# Soil_BD               7718
# Manipulation_level    7722
# Quality_flag          7942
# Rs_annual_err         7975
# Soil_CN               8096
# dtype: int64
